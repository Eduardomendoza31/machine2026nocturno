# %%
# ITQ
## PAO 2025-2026
**Nombre:** *Eduardo Mendoza* <br>
**Fecha:** *07/01/2026*
# Out:
#   Cell In[6], line 4
#     **Fecha:** *07/01/2026*
#                 ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# <h1>Introducción a Pyton</h1>
# Pyton es un lneguaje de programación de alto nivel.<br>
# Tambien pyton me permite hacer aplicaciones de escritorio o web.
# <img

# %%
#Aqui va un comentario
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# https://github.com/Eduardomendoza31/machine2026nocturno.git
